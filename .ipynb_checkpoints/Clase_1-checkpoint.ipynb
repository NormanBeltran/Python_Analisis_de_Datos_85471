# %% [markdown]
# # Clase 1
#
# ## Conceptos
#
# - ipynb significa Interactive Python Notebook
# - Jupyter / Colabs / VS Code + Extensión de Jupyter
#
# ## Diferentes herramientas de uso de Notebooks
#
# ## Estructuras de Python para Datos

# %% [markdown]
# ## Tipos de datos básicos
#
# - Enteros (int)
# - Flotantes (float)
# - Complejos (complex)
# - Cadenas de Texto (strings)
# - Booleanos (boolean)
#
# "Todo en Pyhon es un objeto" (tipos de datos básicos, funciones, objetos)

# %%
c = 1 + 5j

# %%
type(c)
# Out:
# complex

# %% [markdown]
# ## Tipado dinámico
#
# - Simplemente asignando un valor a una variable Python la reconoce por un tipo

# %%
a = 1000
type(a)
# Out:
# int

# %%
a = 1000.10
type(a)
# Out:
# float

# %%
a = "Hola"
type(a)
# Out:
# str

# %%
l1 = [1,2,3]
l2 = l1
l3 = [1,2,3]

# %%
type(l1)
# Out:
# list

# %%
l1[0] = 9999

# %%
l1
# Out:
# [9999, 2, 3]

# %%
l2
# Out:
# [9999, 2, 3]

# %%
l3
# Out:
# [1, 2, 3]

# %%
id(l1), id(l2)
# Out:
# (2400922784320, 2400922784320)

# %%
id(l3)
# Out:
# 2400900280448
